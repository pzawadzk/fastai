# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %%
from fastai.vision import *

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %%
path = Path('data')

# %%
path.ls()
# Out:
# [PosixPath('data/austria.csv'),
#  PosixPath('data/denmark.csv'),
#  PosixPath('data/monaco.csv'),
#  PosixPath('data/peru.csv'),
#  PosixPath('data/poland.csv'),
#  PosixPath('data/swiss.csv')]

# %% [markdown]
# You will need to run this line once per each category.

# %%
classes = ['austria','denmark','monaco', 'peru', 'poland', 'swiss']

# %%
for folder in classes:
    dest = path/folder
    dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('data/austria'),
#  PosixPath('data/austria.csv'),
#  PosixPath('data/denmark'),
#  PosixPath('data/denmark.csv'),
#  PosixPath('data/monaco'),
#  PosixPath('data/monaco.csv'),
#  PosixPath('data/peru'),
#  PosixPath('data/peru.csv'),
#  PosixPath('data/poland'),
#  PosixPath('data/poland.csv'),
#  PosixPath('data/swiss'),
#  PosixPath('data/swiss.csv')]

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download you images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename and the destination folder and this function will download and save all images that can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
path.ls()
# Out:
# [PosixPath('data/austria'),
#  PosixPath('data/austria.csv'),
#  PosixPath('data/denmark'),
#  PosixPath('data/denmark.csv'),
#  PosixPath('data/monaco'),
#  PosixPath('data/monaco.csv'),
#  PosixPath('data/peru'),
#  PosixPath('data/peru.csv'),
#  PosixPath('data/poland'),
#  PosixPath('data/poland.csv'),
#  PosixPath('data/swiss'),
#  PosixPath('data/swiss.csv')]

# %%
for c in classes:
    dest = path/c
    file = c +'.csv'
    print(dest, file)
    download_images(path/file, dest, max_pics=200)
# Out:
# data/austria austria.csv
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='169' class='' max='169', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [169/169 00:31<00:00]
#     </div>
# Error https://h.b5z.net/i/ui/4000204/i/ec/Austria-Flag-grille-badge_i2.jpg HTTPSConnectionPool(host='h.b5z.net', port=443): Max retries exceeded with url: /i/ui/4000204/i/ec/Austria-Flag-grille-badge_i2.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error http://www.flags.net/images/largeflags/AUST0102.GIF HTTPConnectionPool(host='www.flags.net', port=80): Max retries exceeded with url: /images/largeflags/AUST0102.GIF (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1a28574518>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Error https://www.flaginstitute.org/wp/wp-content/uploads/2015/02/Latvia-300x150.png HTTPSConnectionPool(host='www.flaginstitute.org', port=443): Max retries exceeded with url: /wp/wp-content/uploads/2015/02/Latvia-300x150.png (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1a2794d9e8>: Failed to establish a new connection: [Errno 61] Connection refused'))
# data/denmark denmark.csv
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:48<00:00]
#     </div>
#  Download of https://www.onlinestores.com/media/catalog/product/cache/5/image/9df78eab33525d08d6e5fb8d27136e95/d/e/denmark-printed-poly_2.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p /Users/Pawel/.fastai/data
# $ cd /Users/Pawel/.fastai/data
# $ wget -c https://www.onlinestores.com/media/catalog/product/cache/5/image/9df78eab33525d08d6e5fb8d27136e95/d/e/denmark-printed-poly_2.jpg
# $ tar -zxvf denmark-printed-poly_2.jpg
#
# And re-run your code once the download is successful
#
#
#  Download of https://www.united-states-flag.com/media/catalog/product/cache/2/image/9df78eab33525d08d6e5fb8d27136e95/w/d/wdk1218hf_-00_denmark-flag-12-x-18-inch.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p /Users/Pawel/.fastai/data
# $ cd /Users/Pawel/.fastai/data
# $ wget -c https://www.united-states-flag.com/media/catalog/product/cache/2/image/9df78eab33525d08d6e5fb8d27136e95/w/d/wdk1218hf_-00_denmark-flag-12-x-18-inch.jpg
# $ tar -zxvf wdk1218hf_-00_denmark-flag-12-x-18-inch.jpg
#
# And re-run your code once the download is successful
#
#
#  Download of https://i.ytimg.com/vi/Ga86CrzYMnI/maxresdefault.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p /Users/Pawel/.fastai/data
# $ cd /Users/Pawel/.fastai/data
# $ wget -c https://i.ytimg.com/vi/Ga86CrzYMnI/maxresdefault.jpg
# $ tar -zxvf maxresdefault.jpg
#
# And re-run your code once the download is successful
#
#
#  Download of https://www.united-states-flag.com/media/catalog/product/cache/2/image/9df78eab33525d08d6e5fb8d27136e95/f/l/flgfi8i1000011424_-00_denmark-8x12-stick-flag.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p /Users/Pawel/.fastai/data
# $ cd /Users/Pawel/.fastai/data
# $ wget -c https://www.united-states-flag.com/media/catalog/product/cache/2/image/9df78eab33525d08d6e5fb8d27136e95/f/l/flgfi8i1000011424_-00_denmark-8x12-stick-flag.jpg
# $ tar -zxvf flgfi8i1000011424_-00_denmark-8x12-stick-flag.jpg
#
# And re-run your code once the download is successful
#
# Error https://previews.123rf.com/images/jaboy/jaboy1603/jaboy160300622/54616198-denmark-flag-map-icon.jpg HTTPSConnectionPool(host='previews.123rf.com', port=443): Read timed out. (read timeout=4)
# Error https://previews.123rf.com/images/somartin/somartin1402/somartin140200071/25914792-denmark-flag-icon-.jpg HTTPSConnectionPool(host='previews.123rf.com', port=443): Read timed out. (read timeout=4)
# Error https://images.footballfanatics.com/FFImage/thumb.aspx?i=/productimages/_2459000/ff_2459410_full.jpg&w=340 HTTPSConnectionPool(host='images.footballfanatics.com', port=443): Read timed out. (read timeout=4)
# data/monaco monaco.csv
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:22<00:00]
#     </div>
# Error https://images-na.ssl-images-amazon.com/images/I/61ZlcDqavJL._UY395_.jpg HTTPSConnectionPool(host='images-na.ssl-images-amazon.com', port=443): Read timed out. (read timeout=4)
# data/peru peru.csv
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:54<00:00]
#     </div>
# Error https://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productimages/_2458000/altimages/ff_2458904alt1_full.jpg&w=900 HTTPSConnectionPool(host='fanatics.frgimages.com', port=443): Read timed out. (read timeout=4)
# Error https://cdn.countryflags.com/thumbs/peru/flag-wave-250.png HTTPSConnectionPool(host='cdn.countryflags.com', port=443): Read timed out. (read timeout=4)
# data/poland poland.csv
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='168' class='' max='168', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [168/168 00:20<00:00]
#     </div>
# Error https://eu4.paradoxwikis.com/images/thumb/9/99/Poland.png/330px-Poland.png HTTPSConnectionPool(host='eu4.paradoxwikis.com', port=443): Max retries exceeded with url: /images/thumb/9/99/Poland.png/330px-Poland.png (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
#
#  Download of http://c2.peakpx.com/wallpaper/955/903/808/flag-poland-polish-flag-patriotism-wallpaper.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p /Users/Pawel/.fastai/data
# $ cd /Users/Pawel/.fastai/data
# $ wget -c http://c2.peakpx.com/wallpaper/955/903/808/flag-poland-polish-flag-patriotism-wallpaper.jpg
# $ tar -zxvf flag-poland-polish-flag-patriotism-wallpaper.jpg
#
# And re-run your code once the download is successful
#
#
#  Download of https://community-site.solved.fi/wp-content/uploads/2018/07/flag-poland-polish-5611.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p /Users/Pawel/.fastai/data
# $ cd /Users/Pawel/.fastai/data
# $ wget -c https://community-site.solved.fi/wp-content/uploads/2018/07/flag-poland-polish-5611.jpg
# $ tar -zxvf flag-poland-polish-5611.jpg
#
# And re-run your code once the download is successful
#
# data/swiss swiss.csv
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='160' class='' max='160', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [160/160 00:15<00:00]
#     </div>
# Error https://images.footballfanatics.com/FFImage/thumb.aspx?i=/productimages/_2458000/altimages/ff_2458927alt2_full.jpg&w=900 HTTPSConnectionPool(host='images.footballfanatics.com', port=443): Read timed out. (read timeout=4)
# Error https://img.washingtonpost.com/blogs/worldviews/files/2014/04/2014-03-21T173256Z_01_DBA04_RTRIDSP_3_SWITZERLAND.jpg HTTPSConnectionPool(host='img.washingtonpost.com', port=443): Read timed out. (read timeout=4)

# %%
# If you have problems download, try with `max_workers=0` to see exceptions:
#download_images(path/file, dest, max_pics=20, max_workers=0)

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# austria
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='166' class='' max='166', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [166/166 00:03<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='data/austria/00000006.svg'>
# cannot identify image file <_io.BufferedReader name='data/austria/00000005.jpg'>
# Image data/austria/00000012.png has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/austria/00000019.svg'>
# cannot identify image file <_io.BufferedReader name='data/austria/00000020.GIF'>
# Image data/austria/00000021.gif has 1 instead of 3 channels
# Image data/austria/00000030.gif has 1 instead of 3 channels
# Image data/austria/00000032.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/austria/00000034.png'>
# Image data/austria/00000049.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/austria/00000050.GIF'>
# cannot identify image file <_io.BufferedReader name='data/austria/00000047.svg'>
# cannot identify image file <_io.BufferedReader name='data/austria/00000059.svg'>
# Image data/austria/00000060.gif has 1 instead of 3 channels
# Image data/austria/00000063.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/austria/00000073.svg'>
# cannot identify image file <_io.BufferedReader name='data/austria/00000092.GIF'>
# Image data/austria/00000105.png has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/austria/00000129.svg'>
# Image data/austria/00000134.png has 1 instead of 3 channels
# Image data/austria/00000137.png has 4 instead of 3 channels
# Image data/austria/00000143.gif has 1 instead of 3 channels
# Image data/austria/00000159.png has 4 instead of 3 channels
# denmark
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='197' class='' max='197', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [197/197 00:03<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='data/denmark/00000005.jpg'>
# cannot identify image file <_io.BufferedReader name='data/denmark/00000009.jpg'>
# cannot identify image file <_io.BufferedReader name='data/denmark/00000010.jpg'>
# cannot identify image file <_io.BufferedReader name='data/denmark/00000006.jpg'>
# Image data/denmark/00000013.gif has 1 instead of 3 channels
# Image data/denmark/00000014.png has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/denmark/00000031.svg'>
# /anaconda3/lib/python3.7/site-packages/PIL/Image.py:952: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# Image data/denmark/00000045.png has 1 instead of 3 channels
# Image data/denmark/00000054.png has 1 instead of 3 channels
# Image data/denmark/00000058.jpg has 4 instead of 3 channels
# Image data/denmark/00000061.png has 4 instead of 3 channels
# Image data/denmark/00000063.gif has 1 instead of 3 channels
# /anaconda3/lib/python3.7/site-packages/PIL/Image.py:952: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# Image data/denmark/00000095.gif has 1 instead of 3 channels
# Image data/denmark/00000099.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/denmark/00000096.png'>
# /anaconda3/lib/python3.7/site-packages/PIL/Image.py:952: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# Image data/denmark/00000118.png has 1 instead of 3 channels
# Image data/denmark/00000123.png has 1 instead of 3 channels
# /anaconda3/lib/python3.7/site-packages/PIL/Image.py:1005: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry " +
# int() argument must be a string, a bytes-like object or a number, not 'tuple'
# Image data/denmark/00000134.gif has 1 instead of 3 channels
# Image data/denmark/00000135.png has 4 instead of 3 channels
# Image data/denmark/00000140.gif has 1 instead of 3 channels
# Image data/denmark/00000148.png has 4 instead of 3 channels
# Image data/denmark/00000156.png has 1 instead of 3 channels
# Image data/denmark/00000172.png has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/denmark/00000176.svg'>
# Image data/denmark/00000186.gif has 1 instead of 3 channels
# monaco
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='199' class='' max='199', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [199/199 00:03<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='data/monaco/00000003.jpg'>
# Image data/monaco/00000018.gif has 1 instead of 3 channels
# Image data/monaco/00000041.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/monaco/00000042.jpg'>
# Image data/monaco/00000047.gif has 4 instead of 3 channels
# Image data/monaco/00000061.png has 4 instead of 3 channels
# Image data/monaco/00000065.gif has 1 instead of 3 channels
# Image data/monaco/00000070.png has 1 instead of 3 channels
# Image data/monaco/00000072.png has 1 instead of 3 channels
# Image data/monaco/00000080.png has 1 instead of 3 channels
# Image data/monaco/00000082.gif has 1 instead of 3 channels
# Image data/monaco/00000087.png has 1 instead of 3 channels
# Image data/monaco/00000091.png has 1 instead of 3 channels
# Image data/monaco/00000100.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/monaco/00000104.jpg'>
# Image data/monaco/00000112.png has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/monaco/00000124.svg'>
# Image data/monaco/00000126.png has 1 instead of 3 channels
# Image data/monaco/00000133.png has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/monaco/00000139.png'>
# Image data/monaco/00000151.png has 1 instead of 3 channels
# Image data/monaco/00000164.ico has 4 instead of 3 channels
# peru
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='198' class='' max='198', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [198/198 00:03<00:00]
#     </div>
# Image data/peru/00000016.png has 1 instead of 3 channels
# Image data/peru/00000017.gif has 1 instead of 3 channels
# Image data/peru/00000019.png has 1 instead of 3 channels
# Image data/peru/00000034.gif has 1 instead of 3 channels
# Image data/peru/00000050.png has 4 instead of 3 channels
# Image data/peru/00000070.gif has 1 instead of 3 channels
# Image data/peru/00000071.png has 1 instead of 3 channels
# Image data/peru/00000072.png has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/peru/00000078.jpg'>
# cannot identify image file <_io.BufferedReader name='data/peru/00000094.jpg'>
# Image data/peru/00000105.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/peru/00000109.jpg'>
# Image data/peru/00000111.gif has 1 instead of 3 channels
# Image data/peru/00000116.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/peru/00000123.jpg'>
# Image data/peru/00000125.png has 1 instead of 3 channels
# Image data/peru/00000129.png has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/peru/00000141.svg'>
# Image data/peru/00000144.GIF has 1 instead of 3 channels
# /anaconda3/lib/python3.7/site-packages/PIL/Image.py:952: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file <_io.BufferedReader name='data/peru/00000167.jpg'>
# cannot identify image file <_io.BufferedReader name='data/peru/00000179.jpg'>
# Image data/peru/00000186.png has 1 instead of 3 channels
# Image data/peru/00000194.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/peru/00000198.jpg'>
# poland
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='167' class='' max='167', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [167/167 00:03<00:00]
#     </div>
# Image data/poland/00000003.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/poland/00000000.svg'>
# cannot identify image file <_io.BufferedReader name='data/poland/00000010.jpg'>
# /anaconda3/lib/python3.7/site-packages/PIL/Image.py:952: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# Image data/poland/00000019.png has 1 instead of 3 channels
# Image data/poland/00000020.png has 4 instead of 3 channels
# Image data/poland/00000026.png has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/poland/00000025.svg'>
# Image data/poland/00000030.png has 4 instead of 3 channels
# Image data/poland/00000031.gif has 1 instead of 3 channels
# Image data/poland/00000038.png has 4 instead of 3 channels
# Image data/poland/00000045.png has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/poland/00000044.svg'>
# Image data/poland/00000059.gif has 1 instead of 3 channels
# image file is truncated (8 bytes not processed)
# image file is truncated (3 bytes not processed)
# Image data/poland/00000074.png has 4 instead of 3 channels
# Image data/poland/00000079.gif has 1 instead of 3 channels
# Image data/poland/00000084.gif has 1 instead of 3 channels
# Image data/poland/00000090.png has 1 instead of 3 channels
# Image data/poland/00000104.png has 1 instead of 3 channels
# Image data/poland/00000105.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/poland/00000128.jpg'>
# cannot identify image file <_io.BufferedReader name='data/poland/00000140.svg'>
# cannot identify image file <_io.BufferedReader name='data/poland/00000143.svg'>
# Image data/poland/00000148.png has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/poland/00000149.svg'>
# Image data/poland/00000151.png has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/poland/00000154.svg'>
# cannot identify image file <_io.BufferedReader name='data/poland/00000155.svg'>
# cannot identify image file <_io.BufferedReader name='data/poland/00000156.svg'>
# cannot identify image file <_io.BufferedReader name='data/poland/00000158.svg'>
# swiss
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='158' class='' max='158', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [158/158 00:02<00:00]
#     </div>
# Image data/swiss/00000003.png has 1 instead of 3 channels
# Image data/swiss/00000001.gif has 1 instead of 3 channels
# Image data/swiss/00000009.gif has 1 instead of 3 channels
# Image data/swiss/00000021.png has 4 instead of 3 channels
# Image data/swiss/00000024.png has 4 instead of 3 channels
# Image data/swiss/00000033.png has 1 instead of 3 channels
# /anaconda3/lib/python3.7/site-packages/PIL/Image.py:952: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# Image data/swiss/00000060.gif has 1 instead of 3 channels
# Image data/swiss/00000072.png has 4 instead of 3 channels
# Image data/swiss/00000080.jpg has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/swiss/00000086.svg'>
# Image data/swiss/00000090.gif has 1 instead of 3 channels
# Image data/swiss/00000093.gif has 1 instead of 3 channels
# Image data/swiss/00000118.gif has 1 instead of 3 channels
# Image data/swiss/00000129.png has 4 instead of 3 channels

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(do_flip=False), size=224, num_workers=0).normalize(imagenet_stats)

# %%
# If you already cleaned your data, run this cell instead of the one before
# np.random.seed(42)
# data = ImageDataBunch.from_csv(".", folder=".", valid_pct=0.2, csv_labels='cleaned.csv',
#         ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.train_ds
# Out:
# LabelList
# y: CategoryList (756 items)
# [Category austria, Category austria, Category austria, Category austria, Category austria]...
# Path: data
# x: ImageItemList (756 items)
# [Image (3, 333, 500), Image (3, 400, 500), Image (3, 500, 500), Image (3, 281, 500), Image (3, 312, 500)]...
# Path: data

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['austria', 'denmark', 'monaco', 'peru', 'poland', 'swiss'], 6, 756, 189)

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /Users/Pawel/.torch/models/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:21<00:00, 3968752.50it/s]

# %%
learn.fit_one_cycle(4)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/4 00:00<00:00]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='11', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-38-495233eaf2b4>", line 1, in <module>
#     learn.fit_one_cycle(4)
#   File "/anaconda3/lib/python3.7/site-packages/fastai/train.py", line 22, in fit_one_cycle
#     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#   File "/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py", line 178, in fit
#     callbacks=self.callbacks+callbacks)
#   File "/anaconda3/lib/python3.7/site-packages/fastai/utils/mem.py", line 85, in wrapper
#     return func(*args, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py", line 90, in fit
#     loss = loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#   File "/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py", line 20, in loss_batch
#     out = model(*xb)
#   File "/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 489, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py", line 92, in forward
#     input = module(input)
#   File "/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 489, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py", line 92, in forward
#     input = module(input)
#   File "/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 489, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py", line 92, in forward
#     input = module(input)
#   File "/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 489, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/torchvision/models/resnet.py", line 41, in forward
#     out = self.conv1(x)
#   File "/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 489, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 320, in forward
#     self.padding, self.dilation, self.groups)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2018, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/anaconda3/lib/python3.7/inspect.py", line 1500, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/anaconda3/lib/python3.7/inspect.py", line 1458, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/anaconda3/lib/python3.7/inspect.py", line 732, in getmodule
#     for modname, module in list(sys.modules.items()):
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
# Out:
# Total time: 00:11 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.046916</th>
#     <th>0.072489</th>
#     <th>0.027027</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.041749</th>
#     <th>0.070343</th>
#     <th>0.027027</th>
#   </tr>
# </table>

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `ImageCleaner` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)

# %%
ImageCleaner(ds, idxs)
# Out:
# 'No images to show :)'

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. `ImageCleaner` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses.ImageCleaner(ds, idxs)`

# %% [markdown]
# You can also find duplicates in your dataset and delete them! To do this, you need to run `.from_similars` to get the potential duplicates' ids and then run `ImageCleaner` with `duplicates=True`. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.

# %%
ds, idxs = DatasetFormatter().from_similars(learn, ds_type=DatasetType.Valid)
# Out:
# Getting activations...
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:01<00:00]
#     </div>
# Computing similarities...
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='55' class='' max='55', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [55/55 00:00<00:00]
#     </div>

# %%
ImageCleaner(ds, idxs, duplicates=True)
# Out:
# 'No images to show :)'

# %% [markdown]
# Remember to recreate your ImageDataBunch from your `cleaned.csv` to include the changes you made in your data!

# %% [markdown]
# ## Putting your model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
learn.export()

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'black'/'00000021.jpg')
img
# Out:
# Image (3, 220, 300)

# %% [markdown]
# We create our `Learner` in production enviromnent like this, jsut make sure that `path` contains the file 'export.pkl' from before.

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category black

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)
# Out:
# Total time: 00:13
# epoch  train_loss  valid_loss  error_rate
# 1      12.220007   1144188288.000000  0.765957    (00:13)

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result:
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# Total time: 01:07
# epoch  train_loss  valid_loss  error_rate
# 1      1.349151    1.062807    0.609929    (00:13)
# 2      1.373262    1.045115    0.546099    (00:13)
# 3      1.346169    1.006288    0.468085    (00:13)
# 4      1.334486    0.978713    0.453901    (00:13)
# 5      1.320978    0.978108    0.446809    (00:13)

# %%
learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:14
# epoch  train_loss  valid_loss  error_rate
# 1      0.602823    0.119616    0.049645    (00:14)

# %% [markdown]
# ### Too many epochs

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
# Out:
# Total time: 06:39
# epoch  train_loss  valid_loss  error_rate
# 1      1.513021    1.041628    0.507326    (00:13)
# 2      1.290093    0.994758    0.443223    (00:09)
# 3      1.185764    0.936145    0.410256    (00:09)
# 4      1.117229    0.838402    0.322344    (00:09)
# 5      1.022635    0.734872    0.252747    (00:09)
# 6      0.951374    0.627288    0.192308    (00:10)
# 7      0.916111    0.558621    0.184982    (00:09)
# 8      0.839068    0.503755    0.177656    (00:09)
# 9      0.749610    0.433475    0.144689    (00:09)
# 10     0.678583    0.367560    0.124542    (00:09)
# 11     0.615280    0.327029    0.100733    (00:10)
# 12     0.558776    0.298989    0.095238    (00:09)
# 13     0.518109    0.266998    0.084249    (00:09)
# 14     0.476290    0.257858    0.084249    (00:09)
# 15     0.436865    0.227299    0.067766    (00:09)
# 16     0.457189    0.236593    0.078755    (00:10)
# 17     0.420905    0.240185    0.080586    (00:10)
# 18     0.395686    0.255465    0.082418    (00:09)
# 19     0.373232    0.263469    0.080586    (00:09)
# 20     0.348988    0.258300    0.080586    (00:10)
# 21     0.324616    0.261346    0.080586    (00:09)
# 22     0.311310    0.236431    0.071429    (00:09)
# 23     0.328342    0.245841    0.069597    (00:10)
# 24     0.306411    0.235111    0.064103    (00:10)
# 25     0.289134    0.227465    0.069597    (00:09)
# 26     0.284814    0.226022    0.064103    (00:09)
# 27     0.268398    0.222791    0.067766    (00:09)
# 28     0.255431    0.227751    0.073260    (00:10)
# 29     0.240742    0.235949    0.071429    (00:09)
# 30     0.227140    0.225221    0.075092    (00:09)
# 31     0.213877    0.214789    0.069597    (00:09)
# 32     0.201631    0.209382    0.062271    (00:10)
# 33     0.189988    0.210684    0.065934    (00:09)
# 34     0.181293    0.214666    0.073260    (00:09)
# 35     0.184095    0.222575    0.073260    (00:09)
# 36     0.194615    0.229198    0.076923    (00:10)
# 37     0.186165    0.218206    0.075092    (00:09)
# 38     0.176623    0.207198    0.062271    (00:10)
# 39     0.166854    0.207256    0.065934    (00:10)
# 40     0.162692    0.206044    0.062271    (00:09)
